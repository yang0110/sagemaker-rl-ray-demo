# %%
import sagemaker
import boto3
import sys
import os
import glob
import re
import subprocess
import numpy as np
from IPython.display import HTML
import time
from time import gmtime, strftime

sys.path.append("common")
from misc import get_execution_role, wait_for_s3_object
from docker_utils import build_and_push_docker_image
from sagemaker.rl import RLEstimator, RLToolkit, RLFramework

# %%
import os 
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/xxx-rl-mario-ray'

# %%
sage_session = sagemaker.session.Session()
s3_bucket = sage_session.default_bucket()
s3_output_path = "s3://{}/".format(s3_bucket)
print("S3 bucket path: {}".format(s3_output_path))
# Out:
# S3 bucket path: s3://sagemaker-us-east-1-867521064370/

# %%
# create a descriptive job name
job_name_prefix = "rl-mario-ray"

framework = "torch"

# %%
# run in local_mode on this machine, or as a SageMaker TrainingJob?
local_mode = False

if local_mode:
    instance_type = "local"
else:
    # If on SageMaker, pick the instance type.
    instance_type = "ml.p3.8xlarge"

if "ml.p" in instance_type or "ml.g" in instance_type:
    cpu_or_gpu = "gpu"
else:
    cpu_or_gpu = "cpu"

# %%
train_instance_count = 1

# %%
try:
    role = sagemaker.get_execution_role()
except:
    role = get_execution_role()

print("Using IAM role arn: {}".format(role))
# Out:
# Using IAM role arn: arn:aws:iam::867521064370:role/service-role/AmazonSageMaker-ExecutionRole-20220923T161812

# %%
# only run from SageMaker notebook instance
if local_mode:
    # !/bin/bash ./common/setup.sh

# %%
# %%time
if framework == "tf":
    suffix = "py37"
else:
    suffix = "py36"

repository_short_name = "sagemaker-mario-ray-{}-{}".format(cpu_or_gpu, framework)
docker_build_args = {
    "CPU_OR_GPU": cpu_or_gpu,
    "AWS_REGION": boto3.Session().region_name,
    "FRAMEWORK": framework,
    "SUFFIX": suffix,
}

custom_image_name = build_and_push_docker_image(repository_short_name, build_args=docker_build_args)
print("Using ECR image %s" % custom_image_name)
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Logged into ECR
# Building docker image sagemaker-mario-ray-gpu-torch from Dockerfile
# $ docker build -t sagemaker-mario-ray-gpu-torch -f Dockerfile . --build-arg CPU_OR_GPU=gpu --build-arg AWS_REGION=us-east-1 --build-arg FRAMEWORK=torch --build-arg SUFFIX=py36
# Sending build context to Docker daemon  513.5kB
# Step 1/30 : ARG AWS_REGION
# Step 2/30 : ARG CPU_OR_GPU
# Step 3/30 : ARG SUFFIX
# Step 4/30 : ARG VERSION
# Step 5/30 : ARG FRAMEWORK
# Step 6/30 : FROM 462105765813.dkr.ecr.${AWS_REGION}.amazonaws.com/sagemaker-rl-ray-container:ray-1.6.0-${FRAMEWORK}-${CPU_OR_GPU}-${SUFFIX}
#  ---> bad901ccbba6
# Step 7/30 : RUN rm /etc/apt/sources.list.d/cuda.list
#  ---> Using cache
#  ---> c461b889cced
# Step 8/30 : RUN rm /etc/apt/sources.list.d/nvidia-ml.list
#  ---> Using cache
#  ---> b10256ed50d8
# Step 9/30 : RUN apt-get update && apt-get install -y --no-install-recommends         libosmesa6-dev         libgl1-mesa-glx         libglfw3         patchelf         libglew-dev         libglvnd0
#  ---> Using cache
#  ---> ac68e62c9254
# Step 10/30 : RUN apt-get remove -y libglvnd0
#  ---> Using cache
#  ---> c9f264f1d729
# Step 11/30 : RUN apt-get update && apt-get install -y --no-install-recommends         libglvnd0         libglew-dev
#  ---> Using cache
#  ---> af7b5313d8d5
# Step 12/30 : RUN apt-get update && apt-get install -y --no-install-recommends         build-essential         jq         ffmpeg         rsync         libjpeg-dev         libxrender1         python3.7-dev         python3-opengl         wget         xvfb     && apt-get clean     && rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> f1c98ae18278
# Step 13/30 : RUN pip install --upgrade pip
#  ---> Using cache
#  ---> 71057dfeb3c9
# Step 14/30 : RUN pip install gym[atari] autorom[accept-rom-license] pygame gym-super-mario-bros nes_py
#  ---> Using cache
#  ---> 7b9b7ccf62fc
# Step 15/30 : ARG FRAMEWORK
#  ---> Using cache
#  ---> aa1391d1a89e
# Step 16/30 : RUN if [ "${FRAMEWORK}" = "tf" ] ;         then echo 'Installing tensorflow==2.7.0 because it is compatible with numpy>1.20 which is what Mujoco needs.'             && pip uninstall -y tensorflow numpy             && pip install --no-cache-dir tensorflow==2.7.0 ;     fi
#  ---> Using cache
#  ---> a9bd1a085ec2
# Step 17/30 : ENV LC_ALL=C.UTF-8
#  ---> Using cache
#  ---> 85c9e1c6d7ca
# Step 18/30 : ENV LANG=C.UTF-8
#  ---> Using cache
#  ---> 0ee83d0aea41
# Step 19/30 : COPY lib/changehostname.c /
#  ---> Using cache
#  ---> f73087e60c3a
# Step 20/30 : COPY lib/start.sh /usr/local/bin/start.sh
#  ---> Using cache
#  ---> f69a02fea11a
# Step 21/30 : RUN chmod +x /usr/local/bin/start.sh
#  ---> Using cache
#  ---> 7b974e84822f
# Step 22/30 : ENTRYPOINT ["bash", "-m", "start.sh"]
#  ---> Using cache
#  ---> f169840e30f4
# Step 23/30 : RUN pip install sagemaker-containers --upgrade
#  ---> Using cache
#  ---> eb2352768742
# Step 24/30 : ENV PYTHONUNBUFFERED 1
#  ---> Using cache
#  ---> 602a493cd131
# Step 25/30 : RUN python -c "import gym; import sagemaker_containers.cli.train; import gym_super_mario_bros; from sagemaker_containers.cli.train import main"
#  ---> Using cache
#  ---> 7391c0b66d4d
# Step 26/30 : WORKDIR /opt/ml/code
#  ---> Using cache
#  ---> b434631821ab
# Step 27/30 : RUN pip freeze
#  ---> Using cache
#  ---> 45c4a4a77bff
# Step 28/30 : RUN python --version
#  ---> Using cache
#  ---> 2dd31f3225cd
# Step 29/30 : RUN pip show ray
#  ---> Using cache
#  ---> 9b14a74e4127
# Step 30/30 : RUN pip show numpy
#  ---> Using cache
#  ---> 9599bd7ddc2d
# Successfully built 9599bd7ddc2d
# Successfully tagged sagemaker-mario-ray-gpu-torch:latest
# Done building docker image sagemaker-mario-ray-gpu-torch
# ECR repository already exists: sagemaker-mario-ray-gpu-torch
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Logged into ECR
# $ docker tag sagemaker-mario-ray-gpu-torch 867521064370.dkr.ecr.us-east-1.amazonaws.com/sagemaker-mario-ray-gpu-torch
# Pushing docker image to ECR repository 867521064370.dkr.ecr.us-east-1.amazonaws.com/sagemaker-mario-ray-gpu-torch
#
# $ docker push 867521064370.dkr.ecr.us-east-1.amazonaws.com/sagemaker-mario-ray-gpu-torch
# Using default tag: latest
# The push refers to repository [867521064370.dkr.ecr.us-east-1.amazonaws.com/sagemaker-mario-ray-gpu-torch]
# 67f33d8cdd6f: Preparing
# 293cdddc424b: Preparing
# 1e2e47da8303: Preparing
# 6afcfa7b64a6: Preparing
# 99c95ef54b07: Preparing
# 5218db8712cf: Preparing
# ff14e030393a: Preparing
# 4b2b2647c4d2: Preparing
# 4e39ca211fdc: Preparing
# 61895d8cc99d: Preparing
# 6339af8fd27d: Preparing
# 94e8025c2d1c: Preparing
# db17b1a45b10: Preparing
# 9ac997e2f6e8: Preparing
# 2ebdeef7238d: Preparing
# 7497bcba2182: Preparing
# 8075f4eb861d: Preparing
# 1c3de7997a0a: Preparing
# 58e79ce36c01: Preparing
# 9cc8f45faec8: Preparing
# ed34a313e5ef: Preparing
# 5218db8712cf: Waiting
# b6d1822c4b97: Preparing
# 7a2542026e5e: Preparing
# 11815654494b: Preparing
# 012ba9cc20ce: Preparing
# 6339af8fd27d: Waiting
# f791d796d35f: Preparing
# 4b2b2647c4d2: Waiting
# 94e8025c2d1c: Waiting
# a7017dd4d672: Preparing
# d75be732d596: Preparing
# db17b1a45b10: Waiting
# d7699c204fe8: Preparing
# 84748d9d619e: Preparing
# 61895d8cc99d: Waiting
# 9ac997e2f6e8: Waiting
# e97ee5f29336: Preparing
# 2b0e4097f9d8: Preparing
# 4e39ca211fdc: Waiting
# 9aabe01eb0f0: Preparing
# 8b30b07b1164: Preparing
# ff14e030393a: Waiting
# 08e6bebecd68: Preparing
# 4e6ee597a706: Preparing
# 2ebdeef7238d: Waiting
# e3deefc9312b: Preparing
# 11815654494b: Waiting
# d7699c204fe8: Waiting
# 1575b75a53e9: Preparing
# 7497bcba2182: Waiting
# 897552fab726: Preparing
# 84748d9d619e: Waiting
# e7ccdb48d9d6: Preparing
# 012ba9cc20ce: Waiting
# e97ee5f29336: Waiting
# 4c671e8043b1: Preparing
# ed34a313e5ef: Waiting
# f791d796d35f: Waiting
# 35e50ea47ed1: Preparing
# d75be732d596: Waiting
# a7017dd4d672: Waiting
# ecd84ba49d68: Preparing
# 99c0d3a9943d: Preparing
# 3278656ae1af: Preparing
# c1774b9badb2: Preparing
# 1575b75a53e9: Waiting
# 7aa558f04755: Preparing
# 897552fab726: Waiting
# 442e4d9c31a1: Preparing
# e7ccdb48d9d6: Waiting
# ae416b51c19f: Preparing
# 1ea1f19f810d: Preparing
# b6d1822c4b97: Waiting
# 2c5383b8461e: Preparing
# c1774b9badb2: Waiting
# 165686279f58: Preparing
# 442e4d9c31a1: Waiting
# 3278656ae1af: Waiting
# 4c671e8043b1: Waiting
# 7aa558f04755: Waiting
# 08e6bebecd68: Waiting
# 1bab96256033: Preparing
# 35e50ea47ed1: Waiting
# 99c0d3a9943d: Waiting
# 07f364591675: Preparing
# 1c3de7997a0a: Waiting
# ecd84ba49d68: Waiting
# 4e6ee597a706: Waiting
# 3614ee557c99: Preparing
# e3deefc9312b: Waiting
# 2b0e4097f9d8: Waiting
# 9cc8f45faec8: Waiting
# 58e79ce36c01: Waiting
# c35abdcc042f: Preparing
# 9aabe01eb0f0: Waiting
# 07f364591675: Waiting
# 8b30b07b1164: Waiting
# 1ea1f19f810d: Waiting
# ae416b51c19f: Waiting
# 1bab96256033: Waiting
# 165686279f58: Waiting
# 8bfd97b3cc09: Preparing
# 2c5383b8461e: Waiting
# c35abdcc042f: Waiting
# ff672dfe297f: Preparing
# 2864668c16e4: Preparing
# 0d5bccf34cdf: Preparing
# 56f87b339aeb: Preparing
# d7e7872b888e: Preparing
# 5f08512fd434: Preparing
# c7bb31fc0e08: Preparing
# 2864668c16e4: Waiting
# 50858308da3d: Preparing
# 0d5bccf34cdf: Waiting
# d7e7872b888e: Waiting
# 5f08512fd434: Waiting
# c7bb31fc0e08: Waiting
# 50858308da3d: Waiting
# 99c95ef54b07: Layer already exists
# 67f33d8cdd6f: Layer already exists
# 293cdddc424b: Layer already exists
# 6afcfa7b64a6: Layer already exists
# 1e2e47da8303: Layer already exists
# 5218db8712cf: Layer already exists
# ff14e030393a: Layer already exists
# 4e39ca211fdc: Layer already exists
# 4b2b2647c4d2: Layer already exists
# 61895d8cc99d: Layer already exists
# 6339af8fd27d: Layer already exists
# db17b1a45b10: Layer already exists
# 94e8025c2d1c: Layer already exists
# 9ac997e2f6e8: Layer already exists
# 2ebdeef7238d: Layer already exists
# 7497bcba2182: Layer already exists
# 8075f4eb861d: Layer already exists
# 1c3de7997a0a: Layer already exists
# 58e79ce36c01: Layer already exists
# 9cc8f45faec8: Layer already exists
# ed34a313e5ef: Layer already exists
# 7a2542026e5e: Layer already exists
# b6d1822c4b97: Layer already exists
# 11815654494b: Layer already exists
# f791d796d35f: Layer already exists
# 012ba9cc20ce: Layer already exists
# d75be732d596: Layer already exists
# a7017dd4d672: Layer already exists
# d7699c204fe8: Layer already exists
# 84748d9d619e: Layer already exists
# e97ee5f29336: Layer already exists
# 8b30b07b1164: Layer already exists
# 9aabe01eb0f0: Layer already exists
# 2b0e4097f9d8: Layer already exists
# 08e6bebecd68: Layer already exists
# 4e6ee597a706: Layer already exists
# e3deefc9312b: Layer already exists
# 1575b75a53e9: Layer already exists
# e7ccdb48d9d6: Layer already exists
# 897552fab726: Layer already exists
# 4c671e8043b1: Layer already exists
# 35e50ea47ed1: Layer already exists
# ecd84ba49d68: Layer already exists
# 99c0d3a9943d: Layer already exists
# 3278656ae1af: Layer already exists
# c1774b9badb2: Layer already exists
# 7aa558f04755: Layer already exists
# 442e4d9c31a1: Layer already exists
# ae416b51c19f: Layer already exists
# 1ea1f19f810d: Layer already exists
# 2c5383b8461e: Layer already exists
# 1bab96256033: Layer already exists
# 07f364591675: Layer already exists
# 3614ee557c99: Layer already exists
# 165686279f58: Layer already exists
# c35abdcc042f: Layer already exists
# 8bfd97b3cc09: Layer already exists
# ff672dfe297f: Layer already exists
# 0d5bccf34cdf: Layer already exists
# 2864668c16e4: Layer already exists
# d7e7872b888e: Layer already exists
# 5f08512fd434: Layer already exists
# 56f87b339aeb: Layer already exists
# 50858308da3d: Layer already exists
# c7bb31fc0e08: Layer already exists
# latest: digest: sha256:443459c6d14c05528192f0ba40f63ed8b6b25f78f2df28eb59c48569178ce4c6 size: 13960
# Done pushing 867521064370.dkr.ecr.us-east-1.amazonaws.com/sagemaker-mario-ray-gpu-torch
# Using ECR image 867521064370.dkr.ecr.us-east-1.amazonaws.com/sagemaker-mario-ray-gpu-torch
# CPU times: user 146 ms, sys: 121 ms, total: 266 ms
# Wall time: 1.43 s

# %%
# !pygmentize src/train-rl-mario-ray.py
# Out:
# import gym_super_mario_bros
# from gym_super_mario_bros.actions import SIMPLE_MOVEMENT, COMPLEX_MOVEMENT
# from nes_py.wrappers import JoypadSpace
# from ray.rllib.env.wrappers.atari_wrappers import (MonitorEnv,
#                                           NoopResetEnv,
#                                           WarpFrame,
#                                           FrameStack)
# import json
# import os
#
# import gym
# import ray
# from ray.tune import run_experiments
# from ray.tune.registry import register_env
# from sagemaker_rl.ray_launcher import SageMakerRayLauncher
#
# class EpisodicLifeEnv(gym.Wrapper):
#
#     def __init__(self, env):
#         """Make end-of-life == end-of-episode, but only reset on true game
#         over. Done by DeepMind for the DQN and co. since it helps value
#         estimation.
#         """
#         gym.Wrapper.__init__(self, env)
#         self.lives = 0
#         self.was_real_done = True
#
#     def step(self, action):
#         obs, reward, done, info = self.env.step(action)
#         self.was_real_done = done
#         # check current lives, make loss of life terminal,
#         # then update lives to handle bonus lives
#         lives = self.env.unwrapped._life
#         if self.lives > lives > 0:
#             # for Qbert sometimes we stay in lives == 0 condtion for a few fr
#             # so its important to keep lives > 0, so that we only reset once
#             # the environment advertises done.
#             done = True
#         self.lives = lives
#         if info['time']<300:
#             done = True
#         return obs, reward, done, info
#
#     def reset(self, **kwargs):
#         """Reset only when lives are exhausted.
#         This way all states are still reachable even though lives are episodic,
#         and the learner need not know about any of this behind-the-scenes.
#         """
#         if self.was_real_done:
#             obs = self.env.reset(**kwargs)
#         else:
#             # no-op step to advance from terminal/lost life state
#             obs, _, _, _ = self.env.step(0)
#         self.lives = self.env.unwrapped._life
#         return obs
#
#
# class CustomReward(gym.Wrapper):
#     def __init__(self, env):
#         super(CustomReward, self).__init__(env)
#         self._current_score = 0
#
#     def step(self, action):
#         state, reward, done, info = self.env.step(action)
#         reward += (info['score'] - self._current_score) / 40.0
#         self._current_score = info['score']
#         if done:
#             if info['flag_get']:
#                 reward += 350.0
#             else:
#                 reward -= 50.0
#         return state, reward / 10.0, done, info
#
#
# def create_environment(env_config):
#     env = gym_super_mario_bros.make('SuperMarioBros-v0')
#     env = CustomReward(env)
#     env = JoypadSpace(env, COMPLEX_MOVEMENT)
#     env = MonitorEnv(env)
#     env = NoopResetEnv(env, noop_max=30)
#     env = EpisodicLifeEnv(env)
#     env = WarpFrame(env, 84)
#     env = FrameStack(env, 4)
#     return env
#
# class MyLauncher(SageMakerRayLauncher):
#     def register_env_creator(self):
#         register_env('SuperMarioBros-v0', create_environment)
#
#     def get_experiment_config(self):
#         return {
#             "training": {
#                 "env": 'SuperMarioBros-v0',
#                 "run": "IMPALA",
#                 "stop": {"training_iteration": 30},
#                 "config": {
#                     "framework": "torch",
#                     "model": {"free_log_std": True},
#                     "num_workers": (self.num_cpus -1),
#                     "num_gpus": self.num_gpus,
#                     'num_envs_per_worker': 1,
#                     "batch_mode": "truncate_episodes",
#                     'train_batch_size': 5000,
#                 },
#             }
#         }
#
#
# if __name__ == "__main__":
#     MyLauncher().train_main()

# %%
# %%time

metric_definitions = RLEstimator.default_metric_definitions(RLToolkit.RAY)

estimator = RLEstimator(
    entry_point="train-rl-mario-ray.py",
    source_dir="src",
    dependencies=["common/sagemaker_rl"],
    image_uri=custom_image_name,
    role=role,
    debugger_hook_config=False,
    instance_type=instance_type,
    instance_count=train_instance_count,
    output_path=s3_output_path,
    base_job_name=job_name_prefix,
    metric_definitions=metric_definitions,
    hyperparameters={
    },
)

estimator.fit(wait=True)

job_name = estimator.latest_training_job.job_name
print("Training job: %s" % job_name)
# Out:
# 2022-11-09 02:48:38 Starting - Starting the training job...ProfilerReport-1667962118: InProgress
# ...
# 2022-11-09 02:49:28 Starting - Preparing the instances for training........
# 2022-11-09 02:51:06 Downloading - Downloading input data
# 2022-11-09 02:51:06 Training - Downloading the training image......

# %%
# %matplotlib inline
from sagemaker.analytics import TrainingJobAnalytics

# We need to wait for the job to start before we can read metrics from CloudWatch
retry_interval = 30
retry_max_times = 10
current_retry = 0

if not local_mode:

    while current_retry < retry_max_times:
        current_retry += 1
        try:
            df = TrainingJobAnalytics(job_name, ["episode_reward_mean"]).dataframe()
            break
        except:
            print("retry {}".format(current_retry))
            time.sleep(retry_interval)

    df = TrainingJobAnalytics(job_name, ["episode_reward_mean"]).dataframe()
    num_metrics = len(df)
    if num_metrics == 0:
        print("No algorithm metrics found in CloudWatch")
    else:
        plt = df.plot(x="timestamp", y="value", figsize=(12, 5), legend=True, style="b-")
        plt.set_ylabel("Mean reward per episode")
        plt.set_xlabel("Training time (s)")
else:
    print("Can't plot metrics in local mode.")

# %%
if local_mode:
    model_tar_key = "{}/model.tar.gz".format(job_name)
else:
    model_tar_key = "{}/output/model.tar.gz".format(job_name)

tmp_dir = "/tmp/{}".format(job_name)
os.system("mkdir {}".format(tmp_dir))
print("Create local folder {}".format(tmp_dir))
local_checkpoint_dir = "{}/model".format(tmp_dir)

wait_for_s3_object(s3_bucket, model_tar_key, tmp_dir, training_job_name=job_name)

if not os.path.isfile("{}/model.tar.gz".format(tmp_dir)):
    raise FileNotFoundError("File model.tar.gz not found")

os.system("mkdir -p {}".format(local_checkpoint_dir))
os.system("tar -xvzf {}/model.tar.gz -C {}".format(tmp_dir, local_checkpoint_dir))

print("Checkpoint directory {}".format(local_checkpoint_dir))

# %%
if local_mode:
    checkpoint_path = "file://{}".format(local_checkpoint_dir)
    print("Local checkpoint file path: {}".format(local_checkpoint_dir))
else:
    checkpoint_path = "s3://{}/{}/checkpoint/".format(s3_bucket, job_name)
    if not os.listdir(local_checkpoint_dir):
        raise FileNotFoundError("Checkpoint files not found under the path")
    os.system("aws s3 cp --recursive {} {}".format(local_checkpoint_dir, checkpoint_path))
    print("S3 checkpoint file path: {}".format(checkpoint_path))

# %%
# %%time

estimator_eval = RLEstimator(
    entry_point="evaluate-mario-ray.py",
    source_dir="src",
    dependencies=["common/sagemaker_rl"],
    image_uri=custom_image_name,
    role=role,
    instance_type=instance_type,
    instance_count=1,
    base_job_name=job_name_prefix + "-evaluation",
    hyperparameters={"evaluate_episodes": 10, "algorithm": "IMPALA", "env": 'SuperMarioBros-v0'},
)

estimator_eval.fit({"model": checkpoint_path})
job_name = estimator_eval.latest_training_job.job_name
print("Evaluation job: %s" % job_name)
